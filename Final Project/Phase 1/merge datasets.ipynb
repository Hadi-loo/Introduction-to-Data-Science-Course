# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from scipy import stats
import tqdm

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, sum, avg, count, countDistinct
from pyspark.sql.functions import split, explode, when, regexp_extract, substring
from pyspark.sql.functions import date_format, dayofweek, dayofyear, weekofyear, quarter
from pyspark.sql.functions import corr
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler

import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.display import display, HTML
display(HTML('<style>pre { white-space: pre !important; }</style>'))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %% [markdown]
# ### Loading the data

# %%
CSV_DATA_PATH = 'Dataset/spotify.csv'
PARQUET_DATA_PATH = 'Dataset/spotify.parquet'

# %%
spark = SparkSession.builder.appName('spotify').getOrCreate()
df_pyspark = spark.read.parquet(PARQUET_DATA_PATH, header=True, inferSchema=True)
# Out:
# 24/05/27 17:49:36 WARN Utils: Your hostname, hadi resolves to a loopback address: 127.0.1.1; using 192.168.1.5 instead (on interface wlp2s0)
# 24/05/27 17:49:36 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/27 17:49:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/05/27 17:49:58 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
spark2 = SparkSession.builder.appName('spotify').getOrCreate()
df_pyspark2 = spark2.read.csv(CSV_DATA_PATH, header=True, inferSchema=True)

# %%
def show(df_pyspark, n=1):
	print(f'Number of rows: {df_pyspark.count()}')
	df_pyspark.show(n)

# %% [markdown]
# ### Mutual Information

# %%
# find the tracks where track_id in df_pyspark2 is equal to id in df_pyspark
def find_track_id(df_pyspark, df_pyspark2):
	joined_df_pyspark = df_pyspark2.join(df_pyspark, df_pyspark2.track_id == df_pyspark.id, 'inner')
	# return ids of tracks
	return joined_df_pyspark.select('id')

joined_ids = find_track_id(df_pyspark, df_pyspark2)

# %%
# convert joined_ids to list
joined_ids_list = [row.id for row in joined_ids.collect()]
len(joined_ids_list)
# Out:
# 6041

# %%
# select rows where id is in joined_ids_list
df_pyspark1_filtered = df_pyspark.filter(col('id').isin(joined_ids_list))
df_pyspark1_filtered.count()
# Out:
# 4729

# %%
df_pyspark2_filtered = df_pyspark2.filter(col('track_id').isin(joined_ids_list))
df_pyspark2_filtered.count()
# Out:
# 6041

# %%
for i in range(1):
    random_index = np.random.randint(0, len(joined_ids_list))
    df_pyspark.filter(df_pyspark.id == joined_ids_list[random_index]).show()
    df_pyspark2.filter(df_pyspark2.track_id == joined_ids_list[random_index]).show()
# Out:
# +--------------------+---------+--------+--------------------+-----------------+--------------------+------------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+------------------+-------+-------+-----------+--------------+----+------------+
# |                  id|     name|   album|            album_id|          artists|          artist_ids|track_number|disc_number|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|          liveness|valence|  tempo|duration_ms|time_signature|year|release_date|
# +--------------------+---------+--------+--------------------+-----------------+--------------------+------------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+------------------+-------+-------+-----------+--------------+----+------------+
# |1PYsy4cGp3egbeaQD...|Yottabyte|BYLAW EP|5dv1oLETxdsYOkS2S...|['Martin Garrix']|['60d24wfXkVzDSfL...|           2|          1|   false|       0.634| 0.632|  5|   -4.52|   0|     0.0313|      0.0129|         4.53E-4|0.1159999999999999|  0.449|128.075|     210005|           4.0|2018|  2018-10-19|
# +--------------------+---------+--------+--------------------+-----------------+--------------------+------------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+------------------+-------+-------+-----------+--------------+----+------------+
# 24/05/27 17:50:53 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
#  Schema: _c0, track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
# Expected: _c0 but found:
# CSV file: file:///home/hadi/Uni/semester%208/data%20science/projects/Final%20Project/Phase%201/Dataset/spotify.csv
# +-----+--------------------+-------------+----------+----------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------------+
# |  _c0|            track_id|      artists|album_name|track_name|popularity|duration_ms|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|      track_genre|
# +-----+--------------------+-------------+----------+----------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------------+
# |83513|1PYsy4cGp3egbeaQD...|Martin Garrix|  BYLAW EP| Yottabyte|        48|     210004|   False|       0.634| 0.632|  5|   -4.52|   0|     0.0313|      0.0129|         4.53E-4|   0.116|  0.449|128.075|           4.0|progressive-house|
# +-----+--------------------+-------------+----------+----------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------------+

# %%
# add "1_" prefix to columns of df_pyspark1_filtered
df_pyspark1_filtered = df_pyspark1_filtered.toDF(*[f'1_{c}' for c in df_pyspark1_filtered.columns])
df_pyspark1_filtered.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------+----------+------------------+------------------+-----+-------------------+------+-------------+------------------+--------------------+------------------+------------------+------------------+-------------+----------------+------+--------------+
# |                1_id|              1_name|             1_album|          1_album_id|           1_artists|        1_artist_ids|1_track_number|1_disc_number|1_explicit|    1_danceability|          1_energy|1_key|         1_loudness|1_mode|1_speechiness|    1_acousticness|  1_instrumentalness|        1_liveness|         1_valence|           1_tempo|1_duration_ms|1_time_signature|1_year|1_release_date|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------+----------+------------------+------------------+-----+-------------------+------+-------------+------------------+--------------------+------------------+------------------+------------------+-------------+----------------+------+--------------+
# |1wsRitfRRtWyEapl0...|     Guerrilla Radio|The Battle Of Los...|2eia0myWFgoHuttJy...|['Rage Against Th...|['2d0hyoQ5ynDBnkv...|             2|            1|      true|             0.599|             0.957|   11| -5.763999999999999|     1|        0.188|            0.0129|             7.06E-5|             0.155|             0.489|            103.68|       206200|             4.0|  1999|    1999-11-02|
# |2oEXzg6PzHXQ3Mt6A...|        Unholy Water|        Sister Sadie|5ImW9Rgw0hvn5Sh1n...|    ['Sister Sadie']|['0rWSUQEtdCxT9Y1...|             1|            1|     false|             0.461|             0.575|    0|             -7.044|     1|       0.0302|             0.754|              0.0434|             0.315|             0.614|           175.763|       204827|             4.0|  2016|    2016-06-03|
# |4n3mp3DC7JrdXYJCD...|Ana's Song (Open ...|The Best Of - Vol...|0ZDX7TUhxIn3S9PzO...|     ['Silverchair']|['4iudEcmuPlYNdbP...|            15|            1|     false|0.3879999999999999|             0.434|    4|             -9.555|     1|       0.0253|             0.349|             1.66E-4|0.2319999999999999|             0.191|            78.445|       229667|             4.0|  2000|    2000-11-28|
# |79pY2Z5eFvXMt9bSd...|           I Am Mine|            Riot Act|7AOWw68DEPnDmTpqu...|       ['Pearl Jam']|['1w5Kfo2jwwIPruY...|             6|            1|     false|0.3229999999999999|             0.728|    7|             -5.416|     1|       0.0321|           0.00394|   4.469999999999E-4|             0.102|             0.489|           161.586|       215333|             3.0|  2002|    2002-11-08|
# |4OO2lavE7yz5Ane6f...|Everything You Do...|           Hi Scores|3FabCzGQgFLqkCqzc...|['Boards of Canada']|['2VAvhf61GgLYmC6...|             6|            1|     false|              0.54|             0.385|    7|            -13.819|     0|       0.0435|             0.105|               0.916|0.1009999999999999|            0.0875|            91.041|       423933|             4.0|  1996|    1996-12-01|
# |  181|3g61xRaqII8q1wlQD...|        Boyce Avenue|Cover Sessions, V...|      Beautiful Soul|          62|       216612|     False|         0.483|   0.506|    9|    -6.058|     1|       0.0347|         0.394|               0.0|    0.0946|    0.705| 87.337|             4.0|     acoustic|
# |  212|6dwkFmLUz6hx2CZG2...|           Howie Day|Stop All The Worl...|             Collide|          66|       249120|     False|         0.636|   0.625|   11|    -7.895|     1|       0.0277|         0.222|           5.35E-5|     0.119|    0.342| 93.931|             4.0|     acoustic|
# |  216|5auMzVHFr5Zfw6IbK...|         Anna Nalick|    Wreck of the Day|      Breathe (2 AM)|          65|       279826|     False|         0.386|   0.452|    2|    -7.715|     1|       0.0278|         0.417|               0.0|    0.0881|    0.287|169.837|             3.0|     acoustic|
# |  234|1U1GtaJeYwGsPgqV9...|      Ray LaMontagne|             Trouble| Hold You in My Arms|          62|       306200|     False|         0.504|   0.321|    7|   -13.807|     1|       0.0316|         0.149|           1.07E-4|     0.147|    0.577|170.134|             3.0|     acoustic|
# |  243|3M6NL7PxIDZ3ArfPr...|         Days N Daze|Show Me the Bluep...|         Flurry Rush|          37|       169318|      True|         0.371|   0.674|    9|     -3.72|     1|       0.0488|         0.169|               0.0|    0.0889|     0.92| 87.603|             4.0|     acoustic|
# |  266|1nFJAKHt0jgzVogbN...|           Parachute|           Parachute|               Ocean|          48|       222400|     False|         0.662|   0.711|    5|    -4.924|     1|       0.0279|        0.0686|           1.17E-5|     0.085|    0.352|119.989|             4.0|     acoustic|
# +-----+--------------------+--------------------+--------------------+--------------------+------------+-------------+----------+--------------+--------+-----+----------+------+-------------+--------------+------------------+----------+---------+-------+----------------+-------------+
# only showing top 20 rows
# 24/05/27 17:50:55 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
#  Schema: _c0, track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
# Expected: _c0 but found:
# CSV file: file:///home/hadi/Uni/semester%208/data%20science/projects/Final%20Project/Phase%201/Dataset/spotify.csv

# %%
# merge the two dataframes by df_pyspark1_filtered.1_id = df_pyspark2_filtered.2_track_id. only keep the rows which are present in both dataframes
final_df_pyspark = df_pyspark1_filtered.join(df_pyspark2_filtered, df_pyspark1_filtered['1_id'] == df_pyspark2_filtered['2_track_id'], 'inner')
final_df_pyspark.show()
# Out:
# 24/05/27 17:50:55 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/05/27 17:50:57 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
#  Schema: _c0, track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
# Expected: _c0 but found:
# CSV file: file:///home/hadi/Uni/semester%208/data%20science/projects/Final%20Project/Phase%201/Dataset/spotify.csv
# [Stage 20:==============================================>           (4 + 1) / 5]
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------+----------+------------------+------------------+-----+-------------------+------+------------------+------------------+------------------+------------------+------------------+------------------+-------------+----------------+------+--------------+-----+--------------------+--------------------+--------------------+--------------------+------------+-------------+----------+--------------+--------+-----+----------+------+-------------+--------------+------------------+----------+---------+-------+----------------+-------------+
# |                1_id|              1_name|             1_album|          1_album_id|           1_artists|        1_artist_ids|1_track_number|1_disc_number|1_explicit|    1_danceability|          1_energy|1_key|         1_loudness|1_mode|     1_speechiness|    1_acousticness|1_instrumentalness|        1_liveness|         1_valence|           1_tempo|1_duration_ms|1_time_signature|1_year|1_release_date|2__c0|          2_track_id|           2_artists|        2_album_name|        2_track_name|2_popularity|2_duration_ms|2_explicit|2_danceability|2_energy|2_key|2_loudness|2_mode|2_speechiness|2_acousticness|2_instrumentalness|2_liveness|2_valence|2_tempo|2_time_signature|2_track_genre|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------+-------------+----------+------------------+------------------+-----+-------------------+------+------------------+------------------+------------------+------------------+------------------+------------------+-------------+----------------+------+--------------+-----+--------------------+--------------------+--------------------+--------------------+------------+-------------+----------+--------------+--------+-----+----------+------+-------------+--------------+------------------+----------+---------+-------+----------------+-------------+
#
WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
#  Schema: _c0, track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
# Expected: _c0 but found:
# CSV file: file:///home/hadi/Uni/semester%208/data%20science/projects/Final%20Project/Phase%201/Dataset/spotify.csv
# [Stage 32:===========>                                              (1 + 4) / 5]
# +--------------------+---------------+----------------+--------------------+---------------+--------------------+--------------+-------------+----------+--------------+--------+-----+----------+------+-------------+--------------+------------------+------------------+---------+-------+-------------+----------------+------+--------------+-----+--------------------+-----------+----------------+---------------+------------+-------------+----------+--------------+--------+-----+----------+------+-------------+--------------+------------------+----------+---------+-------+----------------+-------------+
# |                1_id|         1_name|         1_album|          1_album_id|      1_artists|        1_artist_ids|1_track_number|1_disc_number|1_explicit|1_danceability|1_energy|1_key|1_loudness|1_mode|1_speechiness|1_acousticness|1_instrumentalness|        1_liveness|1_valence|1_tempo|1_duration_ms|1_time_signature|1_year|1_release_date|2__c0|          2_track_id|  2_artists|    2_album_name|   2_track_name|2_popularity|2_duration_ms|2_explicit|2_danceability|2_energy|2_key|2_loudness|2_mode|2_speechiness|2_acousticness|2_instrumentalness|2_liveness|2_valence|2_tempo|2_time_signature|2_track_genre|
# +--------------------+---------------+----------------+--------------------+---------------+--------------------+--------------+-------------+----------+--------------+--------+-----+----------+------+-------------+--------------+------------------+------------------+---------+-------+-------------+----------------+------+--------------+-----+--------------------+-----------+----------------+---------------+------------+-------------+----------+--------------+--------+-----+----------+------+-------------+--------------+------------------+----------+---------+-------+----------------+-------------+
# |1BLOVHYYlH4JUHQGc...|Ode To The Mets|The New Abnormal|2xkZV2Hl1Omi8rk2D...|['The Strokes']|['0epOFNiUfyON9EY...|             9|            1|     false|         0.428|   0.617|    1|    -5.424|     0|       0.0283|         0.346|             0.179|0.1009999999999999|    0.216| 92.003|       351787|             4.0|  2020|    2020-04-10| 2806|1BLOVHYYlH4JUHQGc...|The Strokes|The New Abnormal|Ode To The Mets|          67|       351786|     False|         0.426|   0.617|    1|    -5.423|     0|       0.0289|         0.341|             0.181|     0.101|    0.201| 92.002|             4.0|     alt-rock|
# +--------------------+---------------+----------------+--------------------+---------------+--------------------+--------------+-------------+----------+--------------+--------+-----+----------+------+-------------+--------------+------------------+------------------+---------+-------+-------------+----------------+------+--------------+-----+--------------------+-----------+----------------+---------------+------------+-------------+----------+--------------+--------+-----+----------+------+-------------+--------------+------------------+----------+---------+-------+----------------+-------------+
# only showing top 1 row

# %%
# convert final_df_pyspark to pandas dataframe
final_df_pandas = final_df_pyspark.toPandas()
final_df_pandas.head()
# Out:
# 24/05/27 17:51:34 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
#  Schema: _c0, track_id, artists, album_name, track_name, popularity, duration_ms, explicit, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature, track_genre
# Expected: _c0 but found:
# CSV file: file:///home/hadi/Uni/semester%208/data%20science/projects/Final%20Project/Phase%201/Dataset/spotify.csv
#                      1_id                                  1_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                     1_album              1_album_id  \
# 0          The New Abnormal  2xkZV2Hl1Omi8rk2D7t5lN
# 1                     Bloom  4N11Xw4rtuswjOeZjqKgay
# 2               Pink Season  3l5PdpQHvUOXlq1w9PftPu
# 3  Speak Your Mind (Deluxe)  7lPoGKpCGgdKFAxpudhAH5
# 4             Twice As Tall  218CJKDCszsQQj7Amk7vIu
#
#                        1_artists  \
# 0                ['The Strokes']
# 1            ['Lights & Motion']
# 2                   ['Pink Guy']
# 3                 ['Anne-Marie']
# 4  ['Burna Boy', 'Chris Martin']
#
#                                         1_artist_ids  1_track_number  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']               9
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']               4
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']              11
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']              10
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...              12
#
#    1_disc_number  1_explicit  1_danceability  ...  2_loudness  2_mode  \
# 0              1       False          0.4280  ...      -5.423       0
# 1              1       False          0.0789  ...     -18.144       1
# 2              1        True          0.8700  ...       -6.32       1
# 3              1       False          0.6970  ...      -2.881       0
# 4              1        True          0.6710  ...      -7.513       0
#
#    2_speechiness  2_acousticness  2_instrumentalness  2_liveness  2_valence  \
# 0         0.0289           0.341            0.181000       0.101      0.201
# 1         0.0362           0.733            0.786000      0.0943     0.0409
# 2          0.333         0.00661            0.000001        0.45      0.533
# 3          0.117          0.0372            0.000000       0.137      0.603
# 4          0.195           0.272            0.000000       0.405      0.355
#
#    2_tempo  2_time_signature  2_track_genre
# 0   92.002               4.0       alt-rock
# 1   56.449               4.0        ambient
# 2  104.021               4.0         comedy
# 3   96.133               4.0          dance
# 4  142.000               4.0      dancehall
#
# [5 rows x 45 columns]

# %%
final_df_pandas.columns
# Out:
# Index(['1_id', '1_name', '1_album', '1_album_id', '1_artists', '1_artist_ids',
#        '1_track_number', '1_disc_number', '1_explicit', '1_danceability',
#        '1_energy', '1_key', '1_loudness', '1_mode', '1_speechiness',
#        '1_acousticness', '1_instrumentalness', '1_liveness', '1_valence',
#        '1_tempo', '1_duration_ms', '1_time_signature', '1_year',
#        '1_release_date', '2__c0', '2_track_id', '2_artists', '2_album_name',
#        '2_track_name', '2_popularity', '2_duration_ms', '2_explicit',
#        '2_danceability', '2_energy', '2_key', '2_loudness', '2_mode',
#        '2_speechiness', '2_acousticness', '2_instrumentalness', '2_liveness',
#        '2_valence', '2_tempo', '2_time_signature', '2_track_genre'],
#       dtype='object')

# %%
# reorder columns of final_df_pandas
final_df_pandas = final_df_pandas[['1_id', '2_track_id', 
                                   '1_name', '2_track_name', 
								   '1_album', '2_album_name',
                                   '1_artists', '2_artists',
                                   '1_explicit', '2_explicit',
                                   '1_danceability', '2_danceability',
                                   '1_energy', '2_energy',
                                   '1_key', '2_key',
                                   '1_loudness', '2_loudness',
                                   '1_mode', '2_mode',
                                   '1_speechiness', '2_speechiness',
                                   '1_acousticness', '2_acousticness',
                                   '1_instrumentalness', '2_instrumentalness',
                                   '1_liveness', '2_liveness',
                                   '1_valence', '2_valence',
                                   '1_tempo', '2_tempo',
                                   '1_time_signature', '2_time_signature',
                                   '1_artist_ids', 
                                   '1_album_id',
                                   '1_track_number', 
                                   '1_disc_number', 
                                   '1_duration_ms',
                                   '1_year', 
                                   '1_release_date',
                                   '2_popularity',
                                   '2_track_genre',
									]] 
final_df_pandas.head()
# Out:
#                      1_id              2_track_id  \
# 0  1BLOVHYYlH4JUHQGcpt75R  1BLOVHYYlH4JUHQGcpt75R
# 1  2No1A7ZuMaBGxz45jmA9Gw  2No1A7ZuMaBGxz45jmA9Gw
# 2  2v738AcSrqklWKhBpV5alf  2v738AcSrqklWKhBpV5alf
# 3  2BgEsaKNfHUdlh97KmvFyo  2BgEsaKNfHUdlh97KmvFyo
# 4  2cerDm5EbuTNJ68EIMtrF2  2cerDm5EbuTNJ68EIMtrF2
#
#                                    1_name  \
# 0                         Ode To The Mets
# 1                                Glaciers
# 2                              Uber Pussy
# 3                                    2002
# 4  Monsters You Made (feat. Chris Martin)
#
#                              2_track_name                   1_album  \
# 0                         Ode To The Mets          The New Abnormal
# 1                                Glaciers                     Bloom
# 2                              Uber Pussy               Pink Season
# 3                                    2002  Speak Your Mind (Deluxe)
# 4  Monsters You Made (feat. Chris Martin)             Twice As Tall
#
#                2_album_name                      1_artists  \
# 0          The New Abnormal                ['The Strokes']
# 1                     Bloom            ['Lights & Motion']
# 2               Pink Season                   ['Pink Guy']
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']
#
#                 2_artists  1_explicit 2_explicit  ...  2_time_signature  \
# 0             The Strokes       False      False  ...               4.0
# 1         Lights & Motion       False      False  ...               4.0
# 2                Pink Guy        True       True  ...               4.0
# 3              Anne-Marie       False      False  ...               4.0
# 4  Burna Boy;Chris Martin        True       True  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#   1_track_number  1_disc_number 1_duration_ms  1_year 1_release_date  \
# 0              9              1        351787    2020     2020-04-10
# 1              4              1        176373    2018     2018-02-02
# 2             11              1        117361    2017     2017-01-04
# 3             10              1        186987    2018     2018-04-27
# 4             12              1        217541    2020     2020-08-13
#
#    2_popularity 2_track_genre
# 0            67      alt-rock
# 1            49       ambient
# 2            39        comedy
# 3            82         dance
# 4            45     dancehall
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Drop Duplicates

# %%
# drop duplicate rows
print(final_df_pandas.shape)
final_df_pandas.drop_duplicates(inplace=True)
print(final_df_pandas.shape)
# Out:
# (6041, 43)
# (6027, 43)

# %% [markdown]
# ### Converting Genre to List

# %%
(final_df_pandas['1_id'] == final_df_pandas['2_track_id']).all()
# Out:
# True

# %%
final_df_pandas.drop('2_track_id', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_id': 'track_id'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                                  1_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                              2_track_name                   1_album  \
# 0                         Ode To The Mets          The New Abnormal
# 1                                Glaciers                     Bloom
# 2                              Uber Pussy               Pink Season
# 3                                    2002  Speak Your Mind (Deluxe)
# 4  Monsters You Made (feat. Chris Martin)             Twice As Tall
#
#                2_album_name                      1_artists  \
# 0          The New Abnormal                ['The Strokes']
# 1                     Bloom            ['Lights & Motion']
# 2               Pink Season                   ['Pink Guy']
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']
#
#                 2_artists  1_explicit 2_explicit  1_danceability  ...  \
# 0             The Strokes       False      False          0.4280  ...
# 1         Lights & Motion       False      False          0.0789  ...
# 2                Pink Guy        True       True          0.8700  ...
# 3              Anne-Marie       False      False          0.6970  ...
# 4  Burna Boy;Chris Martin        True       True          0.6710  ...
#
#   2_time_signature                                       1_artist_ids  \
# 0              4.0                         ['0epOFNiUfyON9EYx7Tpr6V']
# 1              4.0                         ['3ff1CmU6qfTqRAmdrq8EEG']
# 2              4.0                         ['3yJnBqAoRUNeDabdYoiYWD']
# 3              4.0                         ['1zNqDE7qDGCsyzJwohVaoX']
# 4              4.0  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...
#
#                1_album_id  1_track_number 1_disc_number  1_duration_ms 1_year  \
# 0  2xkZV2Hl1Omi8rk2D7t5lN               9             1         351787   2020
# 1  4N11Xw4rtuswjOeZjqKgay               4             1         176373   2018
# 2  3l5PdpQHvUOXlq1w9PftPu              11             1         117361   2017
# 3  7lPoGKpCGgdKFAxpudhAH5              10             1         186987   2018
# 4  218CJKDCszsQQj7Amk7vIu              12             1         217541   2020
#
#    1_release_date 2_popularity  2_track_genre
# 0      2020-04-10           67       alt-rock
# 1      2018-02-02           49        ambient
# 2      2017-01-04           39         comedy
# 3      2018-04-27           82          dance
# 4      2020-08-13           45      dancehall
#
# [5 rows x 42 columns]

# %%
# now if we have a track with multiple genres, we have multiple rows for that track. we will keep only one row for each track and a list of genres for that track
temp = final_df_pandas.groupby('track_id')['2_track_genre'].apply(list).reset_index()
temp.head()
# Out:
#                  track_id     2_track_genre
# 0  000qpdoc97IMTBvF8gwcpy  [minimal-techno]
# 1  001YQlnDSduXd5LgBd66gT  [punk-rock, ska]
# 2  00BYitnjj9tACCkLapk5uS          [grunge]
# 3  00Y9r5SfbDdEjJhNg7laQr          [german]
# 4  00yJsUfhS7Tp3mPMbgmjoJ          [german]

# %%
# show a row with multiple genres
for row in temp.iterrows():
	if len(row[1]['2_track_genre']) > 2:
		print(row[1])
		print("==========")
		print(final_df_pandas['2_track_genre'][final_df_pandas['track_id'] == row[1]['track_id']])
		break
# Out:
# track_id                           02shCNmb6IvgB5jLqKjtkK
# 2_track_genre    [edm, electro, house, progressive-house]
# Name: 22, dtype: object
# ==========
# 2914                  edm
# 2916              electro
# 3994                house
# 5193    progressive-house
# Name: 2_track_genre, dtype: object

# %%
final_df_pandas.drop('2_track_genre', axis=1, inplace=True)
final_df_pandas.drop_duplicates(inplace=True)
final_df_pandas = final_df_pandas.merge(temp, on='track_id', how='left')
final_df_pandas.head()
# Out:
#                  track_id                                  1_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                              2_track_name                   1_album  \
# 0                         Ode To The Mets          The New Abnormal
# 1                                Glaciers                     Bloom
# 2                              Uber Pussy               Pink Season
# 3                                    2002  Speak Your Mind (Deluxe)
# 4  Monsters You Made (feat. Chris Martin)             Twice As Tall
#
#                2_album_name                      1_artists  \
# 0          The New Abnormal                ['The Strokes']
# 1                     Bloom            ['Lights & Motion']
# 2               Pink Season                   ['Pink Guy']
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']
#
#                 2_artists  1_explicit 2_explicit  1_danceability  ...  \
# 0             The Strokes       False      False          0.4280  ...
# 1         Lights & Motion       False      False          0.0789  ...
# 2                Pink Guy        True       True          0.8700  ...
# 3              Anne-Marie       False      False          0.6970  ...
# 4  Burna Boy;Chris Martin        True       True          0.6710  ...
#
#   2_time_signature                                       1_artist_ids  \
# 0              4.0                         ['0epOFNiUfyON9EYx7Tpr6V']
# 1              4.0                         ['3ff1CmU6qfTqRAmdrq8EEG']
# 2              4.0                         ['3yJnBqAoRUNeDabdYoiYWD']
# 3              4.0                         ['1zNqDE7qDGCsyzJwohVaoX']
# 4              4.0  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...
#
#                1_album_id  1_track_number 1_disc_number  1_duration_ms 1_year  \
# 0  2xkZV2Hl1Omi8rk2D7t5lN               9             1         351787   2020
# 1  4N11Xw4rtuswjOeZjqKgay               4             1         176373   2018
# 2  3l5PdpQHvUOXlq1w9PftPu              11             1         117361   2017
# 3  7lPoGKpCGgdKFAxpudhAH5              10             1         186987   2018
# 4  218CJKDCszsQQj7Amk7vIu              12             1         217541   2020
#
#    1_release_date 2_popularity        2_track_genre
# 0      2020-04-10           67   [alt-rock, garage]
# 1      2018-02-02           49            [ambient]
# 2      2017-01-04           39             [comedy]
# 3      2018-04-27           82  [dance, house, pop]
# 4      2020-08-13           45          [dancehall]
#
# [5 rows x 42 columns]

# %%
temp = final_df_pandas.groupby('track_id')
count = 0
# show groups with more than one row
for name, group in temp:
	if count == 5:
		break
	if len(group) > 1:
		if group['2_popularity'].nunique() == 1:	
			print(group)
			print("==========")
			count += 1

# %%
for name, group in temp:
	if (len(group) > 1) and (group['2_popularity'].nunique() != 1):
		# keep only the first row in group
		final_df_pandas.drop(group.index[1:], inplace=True)

final_df_pandas.reset_index(drop=True, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                                  1_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                              2_track_name                   1_album  \
# 0                         Ode To The Mets          The New Abnormal
# 1                                Glaciers                     Bloom
# 2                              Uber Pussy               Pink Season
# 3                                    2002  Speak Your Mind (Deluxe)
# 4  Monsters You Made (feat. Chris Martin)             Twice As Tall
#
#                2_album_name                      1_artists  \
# 0          The New Abnormal                ['The Strokes']
# 1                     Bloom            ['Lights & Motion']
# 2               Pink Season                   ['Pink Guy']
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']
#
#                 2_artists  1_explicit 2_explicit  1_danceability  ...  \
# 0             The Strokes       False      False          0.4280  ...
# 1         Lights & Motion       False      False          0.0789  ...
# 2                Pink Guy        True       True          0.8700  ...
# 3              Anne-Marie       False      False          0.6970  ...
# 4  Burna Boy;Chris Martin        True       True          0.6710  ...
#
#   2_time_signature                                       1_artist_ids  \
# 0              4.0                         ['0epOFNiUfyON9EYx7Tpr6V']
# 1              4.0                         ['3ff1CmU6qfTqRAmdrq8EEG']
# 2              4.0                         ['3yJnBqAoRUNeDabdYoiYWD']
# 3              4.0                         ['1zNqDE7qDGCsyzJwohVaoX']
# 4              4.0  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...
#
#                1_album_id  1_track_number 1_disc_number  1_duration_ms 1_year  \
# 0  2xkZV2Hl1Omi8rk2D7t5lN               9             1         351787   2020
# 1  4N11Xw4rtuswjOeZjqKgay               4             1         176373   2018
# 2  3l5PdpQHvUOXlq1w9PftPu              11             1         117361   2017
# 3  7lPoGKpCGgdKFAxpudhAH5              10             1         186987   2018
# 4  218CJKDCszsQQj7Amk7vIu              12             1         217541   2020
#
#    1_release_date 2_popularity        2_track_genre
# 0      2020-04-10           67   [alt-rock, garage]
# 1      2018-02-02           49            [ambient]
# 2      2017-01-04           39             [comedy]
# 3      2018-04-27           82  [dance, house, pop]
# 4      2020-08-13           45          [dancehall]
#
# [5 rows x 42 columns]

# %%
print(len(final_df_pandas))
print(final_df_pandas['track_id'].nunique())
# Out:
# 4729
# 4729

# %% [markdown]
# ### Merging the columns

# %%
# check if '1_name' and '2_track_name' are equal
(final_df_pandas['1_name'] == final_df_pandas['2_track_name']).all()
# Out:
# False

# %%
final_df_pandas[final_df_pandas['1_name'] != final_df_pandas['2_track_name']]
# Out:
#                     track_id  \
# 21    3KhhGdo024E5njEJBsQUpU
# 37    4KoSQS6Bs9ZjgkdvR7UFJM
# 96    5jjZikDrEd0by1o7V3fO4y
# 131   2GnYCy70I8cR4oEA2wsSDx
# 173   3D8dwH690MXQRhtIZTSS9c
# ...                      ...
# 4673  7kmYuFYVsk3UCIw5wuE6B1
# 4694  7o9PkTfxL0Mm7gk3Bp98hv
# 4702  5s3lnmStpDUDDSJ1curTd7
# 4719  2R26Us31r9gJQhv23xXzuy
# 4721  5z0QLEpkbUh00SevSuYxOh
#
#                                                  1_name  \
# 21                           haveTomorrow's Another Day
# 37                                    No Es Fácil Amar
# 96                                          Overwhelmed
# 131   The Hours: An Unwelcome Friend (From "The Hours")
# 173   Leaving, On a Jet Plane - "Greatest Hits" Version
# ...                                                 ...
# 4673            Love Is A Stranger - Remastered Version
# 4694            I See You Baby - Fatboy Slim Radio Edit
# 4702                    Otra Vez (feat. Sabina Sciubba)
# 4719                       United - Single Long Version
# 4721                            Divine Moments Of Truth
#
#                                            2_track_name  \
# 21                               Tomorrow's Another Day
# 37                                     No Es Fácil Amar
# 96                                          overwhelmed
# 131   "The Hours: An Unwelcome Friend (From ""The Ho...
# 173   "Leaving, On a Jet Plane - ""Greatest Hits"" V...
# ...                                                 ...
# 4673            Love Is a Stranger - Remastered Version
# 4694  I See You Baby (feat. Gramma Funk) - Fatboy Sl...
# 4702                                           Otra Vez
# 4719                       United (Single Long Version)
# 4721                            Divine Moments of Truth
#
#                                           1_album  \
# 21                                   Collie Buddz
# 37                            Super Pop Venezuela
# 96                                    Overwhelmed
# 131   Philip Glass: Glassworlds, Vol. 4 – On Love
# 173                   John Denver's Greatest Hits
# ...                                           ...
# 4673                          Ultimate Collection
# 4694                  Groove Armada Greatest Hits
# 4702                                     Amatoria
# 4719            The Past, The Present, The Future
# 4721                           Are You Shpongled?
#
#                                      2_album_name  \
# 21                                   Collie Buddz
# 37                            Super Pop Venezuela
# 96                                    Overwhelmed
# 131   Philip Glass: Glassworlds, Vol. 4 – On Love
# 173                   John Denver's Greatest Hits
# ...                                           ...
# 4673                          Ultimate Collection
# 4694                  Groove Armada Greatest Hits
# 4702                                     Amatoria
# 4719            The Past, The Present, The Future
# 4721                           Are You Shpongled?
#
#                                            1_artists  \
# 21                                  ['Collie Buddz']
# 37                         ['Los Amigos Invisibles']
# 96                           ['Royal & the Serpent']
# 131              ['Philip Glass', 'Nicolas Horvath']
# 173                                  ['John Denver']
# ...                                              ...
# 4673  ['Eurythmics', 'Annie Lennox', 'Dave Stewart']
# 4694                ['Groove Armada', 'Gramma Funk']
# 4702                             ['Federico Aubele']
# 4719                                    ["Mark 'Oh"]
# 4721                                    ['Shpongle']
#
#                                  2_artists  1_explicit 2_explicit  \
# 21                            Collie Buddz       False      False
# 37                   Los Amigos Invisibles       False      False
# 96                     Royal & the Serpent       False      False
# 131           Philip Glass;Nicolas Horvath       False      False
# 173                            John Denver       False      False
# ...                                    ...         ...        ...
# 4673  Eurythmics;Annie Lennox;Dave Stewart       False      False
# 4694             Groove Armada;Gramma Funk       False      False
# 4702         Federico Aubele;Sabina Sciuba       False      False
# 4719                              Mark 'Oh       False      False
# 4721                              Shpongle       False      False
#
#       1_danceability  ... 2_time_signature  \
# 21             0.706  ...              4.0
# 37             0.732  ...              4.0
# 96             0.804  ...              4.0
# 131            0.253  ...              3.0
# 173            0.406  ...              4.0
# ...              ...  ...              ...
# 4673           0.780  ...              4.0
# 4694           0.572  ...              4.0
# 4702           0.702  ...              4.0
# 4719           0.538  ...              4.0
# 4721           0.447  ...              3.0
#
#                                            1_artist_ids  \
# 21                           ['5Ayl2bJtN5mdCsxZoxs9n1']
# 37                           ['5x3mrCTZmkoTXURN7pWdGN']
# 96                           ['64EHXDoln95lnccszdPum0']
# 131   ['69lxxQvsfAIoQbB20bEPFC', '6EyYsJlQEb3uHINVS5...
# 173                          ['7EK1bQADBoqbYXnT4Cqv9w']
# ...                                                 ...
# 4673  ['0NKDgy9j66h3DLnN8qu1bB', '5MspMQqdVbdwP6ax3G...
# 4694  ['67tgMwUfnmqzYsNAtnP6YJ', '09dzhikZDQAWGs8jyI...
# 4702                         ['3FIFlkBCqeOewVa9hiNgwq']
# 4719                         ['3eLW10XmpXVzwszGQ9gDXX']
# 4721                         ['0m5XJwKGYyUjd3VMfcINCQ']
#
#                   1_album_id  1_track_number 1_disc_number  1_duration_ms  \
# 21    2BGWnHTib774X9f7RPoato               4             1         195800
# 37    06UChHNzoOpOKngPglcvLE               5             1         249520
# 96    7E7HRywUyuqW5qH793yPbP               1             1         159293
# 131   2HItrNjxkcndzejvNPdE6v               7             1         256147
# 173   4zn2Kj85Hew0USyxc4TJEX               6             1         245533
# ...                      ...             ...           ...            ...
# 4673  1t7fYXGuOKQ61AY4qRtIot               2             1         222613
# 4694  4gAC6u1x2Bld7EBhJppCnQ               3             1         244707
# 4702  7u64RVEfkE88QvI2jyWuDW               3             1         194080
# 4719  33ynyiIWIDFpexO0ikTInX               5             1         238307
# 4721  7fAOqI4aJxx5oTeCMLPONf               6             1         620333
#
#      1_year  1_release_date 2_popularity  \
# 21     2007      2007-07-02           34
# 37     2006      2006-09-05           29
# 96     2020      2020-06-26           70
# 131    2016      2016-06-10           59
# 173    1973      1973-11-01           62
# ...     ...             ...          ...
# 4673   2005      2005-11-08           23
# 4694   2007            2007           53
# 4702   2009      2009-05-19           19
# 4719   2009      2009-11-06           25
# 4721   1998      1998-10-01           42
#
#                                        2_track_genre
# 21                                       [dancehall]
# 37                                        [afrobeat]
# 96          [alternative, electro, indie-pop, indie]
# 131                                        [ambient]
# 173   [country, folk, singer-songwriter, songwriter]
# ...                                              ...
# 4673                                     [synth-pop]
# 4694                                      [trip-hop]
# 4702                                      [trip-hop]
# 4719                                        [techno]
# 4721                                        [trance]
#
# [120 rows x 42 columns]

# %%
final_df_pandas.drop('2_track_name', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_name': 'track_name'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                     1_album              2_album_name  \
# 0          The New Abnormal          The New Abnormal
# 1                     Bloom                     Bloom
# 2               Pink Season               Pink Season
# 3  Speak Your Mind (Deluxe)  Speak Your Mind (Deluxe)
# 4             Twice As Tall             Twice As Tall
#
#                        1_artists               2_artists  1_explicit  \
# 0                ['The Strokes']             The Strokes       False
# 1            ['Lights & Motion']         Lights & Motion       False
# 2                   ['Pink Guy']                Pink Guy        True
# 3                 ['Anne-Marie']              Anne-Marie       False
# 4  ['Burna Boy', 'Chris Martin']  Burna Boy;Chris Martin        True
#
#   2_explicit  1_danceability 2_danceability  ...  2_time_signature  \
# 0      False          0.4280          0.426  ...               4.0
# 1      False          0.0789         0.0789  ...               4.0
# 2       True          0.8700           0.87  ...               4.0
# 3      False          0.6970          0.697  ...               4.0
# 4       True          0.6710          0.671  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#   1_track_number  1_disc_number 1_duration_ms  1_year 1_release_date  \
# 0              9              1        351787    2020     2020-04-10
# 1              4              1        176373    2018     2018-02-02
# 2             11              1        117361    2017     2017-01-04
# 3             10              1        186987    2018     2018-04-27
# 4             12              1        217541    2020     2020-08-13
#
#    2_popularity        2_track_genre
# 0            67   [alt-rock, garage]
# 1            49            [ambient]
# 2            39             [comedy]
# 3            82  [dance, house, pop]
# 4            45          [dancehall]
#
# [5 rows x 41 columns]

# %%
(final_df_pandas['1_album'] == final_df_pandas['2_album_name']).all()
# Out:
# False

# %%
final_df_pandas[final_df_pandas['1_album'] != final_df_pandas['2_album_name']]
# Out:
#                     track_id  \
# 220   5tsAOP03wpq2WehkxrAakt
# 266   57BuFDoc2hUHmSyoL8OynI
# 308   7afCEhjQKgWLoLOUs0TX4m
# 335   0ROMalDdNg3L2HoZP4qFyJ
# 337   1u8T5EVNoIP7bxcn4ZMlsm
# ...                      ...
# 4624  35kPxG6AKmgsRPiKoiLsBr
# 4639  42bdU7oDyRvyRXaKbUrtfu
# 4646  2JQTce5g0LUUVvhtEFEiGR
# 4670  2y5w00ZbmGhfp1bQytUtDE
# 4688  183eww9uTE7m2gI5gWMWxT
#
#                                              track_name  \
# 220                                     Ships Sail Away
# 266                                      My First Lover
# 308                        I'll Be Mellow When I'm Dead
# 335   The Four Seasons - Winter in F Minor, RV. 297:...
# 337              The Biggest Ball of Twine In Minnesota
# ...                                                 ...
# 4624                                         Journey On
# 4639                            Victory Is Yours (Live)
# 4646                              When The Children Cry
# 4670                            Endless Alleluia (Live)
# 4688                             Till We Reach That Day
#
#                                                 1_album  \
# 220                  Haste Make | Hard Hearted Stranger
# 266                                Time (The Relevator)
# 308                                 "Weird Al" Yankovic
# 335   The Four Seasons & Concertos for Bassoon and V...
# 337                   The Essential "Weird Al" Yankovic
# ...                                                 ...
# 4624  Ragtime: The Musical (Original Broadway Cast R...
# 4639                                            Victory
# 4646                                      Mark &apos;Oh
# 4670                                            Victory
# 4688  Ragtime: The Musical (Original Broadway Cast R...
#
#                                            2_album_name  \
# 220                  Haste Make / Hard Hearted Stranger
# 266                                Time (The Revelator)
# 308                             """Weird Al"" Yankovic"
# 335   "The Four Seasons & Concertos for Bassoon and ...
# 337               "The Essential ""Weird Al"" Yankovic"
# ...                                                 ...
# 4624  Ragtime: The Musical (Original Broadway Cast R...
# 4639                                     Victory (Live)
# 4646                                           Mark 'Oh
# 4670                                     Victory (Live)
# 4688  Ragtime: The Musical (Original Broadway Cast R...
#
#                                               1_artists  \
# 220                                 ['Mandolin Orange']
# 266                                   ['Gillian Welch']
# 308                             ['"Weird Al" Yankovic']
# 335   ['Antonio Vivaldi', 'Adrian Chandler', 'La Ser...
# 337                             ['"Weird Al" Yankovic']
# ...                                                 ...
# 4624  ['Marin Mazzie', 'Peter Friedman', 'Mark Jacob...
# 4639                 ['Bethel Music', 'Bethany Wohrle']
# 4646                                       ["Mark 'Oh"]
# 4670                    ['Bethel Music', 'Cory Asbury']
# 4688  ['Marin Mazzie', 'Peter Friedman', 'Steven Sut...
#
#                                               2_artists  1_explicit  \
# 220                                          Watchhouse       False
# 266                                       Gillian Welch       False
# 308                             """Weird Al"" Yankovic"       False
# 335      Antonio Vivaldi;Adrian Chandler;La Serenissima       False
# 337                             """Weird Al"" Yankovic"       False
# ...                                                 ...         ...
# 4624  Marin Mazzie;Peter Friedman;Mark Jacoby;Rod Ca...       False
# 4639                        Bethel Music;Bethany Wohrle       False
# 4646                                           Mark 'Oh       False
# 4670                           Bethel Music;Cory Asbury       False
# 4688  Marin Mazzie;Peter Friedman;Steven Sutcliffe;V...       False
#
#      2_explicit  1_danceability 2_danceability  ...  2_time_signature  \
# 220       False           0.436           0.42  ...               3.0
# 266       False           0.653          0.653  ...               4.0
# 308       False           0.661          0.661  ...               4.0
# 335       False           0.400            0.4  ...               4.0
# 337       False           0.724          0.724  ...               4.0
# ...         ...             ...            ...  ...               ...
# 4624      False           0.521          0.521  ...               4.0
# 4639      False           0.418          0.418  ...               4.0
# 4646      False           0.476          0.476  ...               4.0
# 4670      False           0.394          0.394  ...               4.0
# 4688      False           0.228          0.228  ...               4.0
#
#                                            1_artist_ids  \
# 220                          ['675tsBPpaZtqyiBwEf3ZEP']
# 266                          ['2H5elA2mJKrHmqkN9GSfkz']
# 308                          ['1bDWGdIC2hardyt55nlQgG']
# 335   ['2QOIawHpSlOwXDvSqQ9YJR', '7qJsLLT3iv2Uc0Xbpn...
# 337                          ['1bDWGdIC2hardyt55nlQgG']
# ...                                                 ...
# 4624  ['26HZcBntJsXRix4UH8VpL8', '4uqPgf1BAv7sl9tNx6...
# 4639  ['26T4yOaOoFJvUvxR87Y9HO', '26opZlzcsx1NhaN5QE...
# 4646                         ['3eLW10XmpXVzwszGQ9gDXX']
# 4670  ['26T4yOaOoFJvUvxR87Y9HO', '2gXmjQIxCO8lMnSncl...
# 4688  ['26HZcBntJsXRix4UH8VpL8', '4uqPgf1BAv7sl9tNx6...
#
#                   1_album_id 1_track_number  1_disc_number 1_duration_ms  \
# 220   5nBEPxMYprdGPngcur3JoV              8              1        216093
# 266   55FP2ypQcghszSqylyBRbp              2              1        227840
# 308   1gnhuWdl30liEUM2jy9lxl             10              1        220907
# 335   1mSVDEox7b18dnZ4Iblnkb             10              1        201853
# 337   2WMY5Qm6ztMQsAubpumeb4             14              1        407480
# ...                      ...            ...            ...           ...
# 4624  1ITaTY1cwy5bnG3Dyoucr1              3              1        253333
# 4639  6EsmModhcfmKIeCeNQjeDY              5              1        333080
# 4646  4bUZMLuz9femb3vIBt1sbb              2              1        232787
# 4670  6EsmModhcfmKIeCeNQjeDY             14              1        323347
# 4688  1ITaTY1cwy5bnG3Dyoucr1             21              1        251133
#
#       1_year 1_release_date  2_popularity  2_track_genre
# 220     2011     2011-11-08            24    [bluegrass]
# 266     2001     2001-07-31            29    [bluegrass]
# 308     1983           1983            26       [comedy]
# 335     2015     2015-09-04            63    [classical]
# 337     2009           2009            22       [comedy]
# ...      ...            ...           ...            ...
# 4624    1998           1998            24   [show-tunes]
# 4639    2019     2019-01-25            44  [world-music]
# 4646    2010     2010-05-21            26       [techno]
# 4670    2019     2019-01-25            45  [world-music]
# 4688    1998           1998            23   [show-tunes]
#
# [86 rows x 41 columns]

# %%
final_df_pandas.drop('2_album_name', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_album': 'album_name'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                      1_artists  \
# 0          The New Abnormal                ['The Strokes']
# 1                     Bloom            ['Lights & Motion']
# 2               Pink Season                   ['Pink Guy']
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']
#
#                 2_artists  1_explicit 2_explicit  1_danceability  \
# 0             The Strokes       False      False          0.4280
# 1         Lights & Motion       False      False          0.0789
# 2                Pink Guy        True       True          0.8700
# 3              Anne-Marie       False      False          0.6970
# 4  Burna Boy;Chris Martin        True       True          0.6710
#
#   2_danceability  1_energy  ... 2_time_signature  \
# 0          0.426     0.617  ...              4.0
# 1         0.0789     0.160  ...              4.0
# 2           0.87     0.597  ...              4.0
# 3          0.697     0.683  ...              4.0
# 4          0.671     0.646  ...              4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number 1_disc_number  1_duration_ms 1_year  1_release_date  \
# 0               9             1         351787   2020      2020-04-10
# 1               4             1         176373   2018      2018-02-02
# 2              11             1         117361   2017      2017-01-04
# 3              10             1         186987   2018      2018-04-27
# 4              12             1         217541   2020      2020-08-13
#
#   2_popularity        2_track_genre
# 0           67   [alt-rock, garage]
# 1           49            [ambient]
# 2           39             [comedy]
# 3           82  [dance, house, pop]
# 4           45          [dancehall]
#
# [5 rows x 40 columns]

# %%
(final_df_pandas['1_artists'] == final_df_pandas['2_artists']).all()
# Out:
# False

# %%
# show rows with same 'track_id'
count = 0
for cur_id in final_df_pandas['track_id'].unique():
	if final_df_pandas[final_df_pandas['track_id'] == cur_id].shape[0] < 2:
		continue
	if count > 5:
		break
	# show the difference between rows with same 'track_id'
	display(final_df_pandas[final_df_pandas['track_id'] == cur_id])
	count += 1

# %%
final_df_pandas[final_df_pandas['1_artists'] != final_df_pandas['2_artists']]
# Out:
#                     track_id                              track_name  \
# 0     1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1     2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2     2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3     2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4     2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
# ...                      ...                                     ...
# 4724  6oF8ueLn5hIl4PRp17sxW6                    That Would Be Enough
# 4725  2qf1Cbi3mIFzVnKERuNwx5                          In This Corner
# 4726  4NUomtCzWb8WNW1DOjCa8A                                El Flete
# 4727  2gVNHsFCboH2rih4HZvRmQ                            It Takes Two
# 4728  3SktMqZmo3M9zbB7oKMIF7                                 Gravity
#
#                                           album_name  \
# 0                                   The New Abnormal
# 1                                              Bloom
# 2                                        Pink Season
# 3                           Speak Your Mind (Deluxe)
# 4                                      Twice As Tall
# ...                                              ...
# 4724     Hamilton (Original Broadway Cast Recording)
# 4725  Kinky Boots (Original Broadway Cast Recording)
# 4726                                    De Pura Cepa
# 4727    Hairspray (Original Broadway Cast Recording)
# 4728                                       Continuum
#
#                                               1_artists  \
# 0                                       ['The Strokes']
# 1                                   ['Lights & Motion']
# 2                                          ['Pink Guy']
# 3                                        ['Anne-Marie']
# 4                         ['Burna Boy', 'Chris Martin']
# ...                                                 ...
# 4724             ['Phillipa Soo', 'Lin-Manuel Miranda']
# 4725  ['Billy Porter', 'Tory Ross', 'Daniel Stewart ...
# 4726            ["Juan D'Arienzo y su Orquesta Típica"]
# 4727  ['Matthew Morrison', 'Marissa Jaret Winokur', ...
# 4728                                     ['John Mayer']
#
#                                               2_artists  1_explicit  \
# 0                                           The Strokes       False
# 1                                       Lights & Motion       False
# 2                                              Pink Guy        True
# 3                                            Anne-Marie       False
# 4                                Burna Boy;Chris Martin        True
# ...                                                 ...         ...
# 4724                    Phillipa Soo;Lin-Manuel Miranda       False
# 4725  Billy Porter;Tory Ross;Daniel Stewart Sherman;...       False
# 4726                Juan D'Arienzo y su Orquesta Típica       False
# 4727  Matthew Morrison;Marissa Jaret Winokur;Hairspr...       False
# 4728                                         John Mayer       False
#
#      2_explicit  1_danceability 2_danceability  1_energy  ...  \
# 0         False          0.4280          0.426     0.617  ...
# 1         False          0.0789         0.0789     0.160  ...
# 2          True          0.8700           0.87     0.597  ...
# 3         False          0.6970          0.697     0.683  ...
# 4          True          0.6710          0.671     0.646  ...
# ...         ...             ...            ...       ...  ...
# 4724      False          0.4990          0.499     0.200  ...
# 4725      False          0.6890          0.689     0.726  ...
# 4726      False          0.8480          0.848     0.381  ...
# 4727      False          0.3140          0.314     0.553  ...
# 4728      False          0.7640          0.753     0.326  ...
#
#      2_time_signature                                       1_artist_ids  \
# 0                 4.0                         ['0epOFNiUfyON9EYx7Tpr6V']
# 1                 4.0                         ['3ff1CmU6qfTqRAmdrq8EEG']
# 2                 4.0                         ['3yJnBqAoRUNeDabdYoiYWD']
# 3                 4.0                         ['1zNqDE7qDGCsyzJwohVaoX']
# 4                 4.0  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...
# ...               ...                                                ...
# 4724              4.0  ['2OEGI2wrCVmvavKEOMlccy', '4aXXDj9aZnlshx7mzj...
# 4725              4.0  ['3sjUEh7eXUEL5oZLAEZXD4', '5zwDN0Orwiu22wYaxl...
# 4726              4.0                         ['3EZYBGl6qytwvUPRBVQgOP']
# 4727              3.0  ['3Fx1vJHj530oWC2AxnZq5z', '4zdCODAJOsWFl6I9H7...
# 4728              3.0                         ['0hEurMDQu99nJRq8pTxO14']
#
#                   1_album_id  1_track_number 1_disc_number  1_duration_ms  \
# 0     2xkZV2Hl1Omi8rk2D7t5lN               9             1         351787
# 1     4N11Xw4rtuswjOeZjqKgay               4             1         176373
# 2     3l5PdpQHvUOXlq1w9PftPu              11             1         117361
# 3     7lPoGKpCGgdKFAxpudhAH5              10             1         186987
# 4     218CJKDCszsQQj7Amk7vIu              12             1         217541
# ...                      ...             ...           ...            ...
# 4724  1kCHru7uhxBUdzkm4gzRQc              17             1         178446
# 4725  0VfNZpKsykX5WPuyEdBilR              11             1         296800
# 4726  02OrTuXLp4AT6uGFiEVYeB               9             1         173640
# 4727  3XPjEfpawBvohxBMDXwXXW               6             1         186027
# 4728  1Xsprdt1q9rOzTic7b9zYM               4             1         245827
#
#      1_year  1_release_date 2_popularity                    2_track_genre
# 0      2020      2020-04-10           67               [alt-rock, garage]
# 1      2018      2018-02-02           49                        [ambient]
# 2      2017      2017-01-04           39                         [comedy]
# 3      2018      2018-04-27           82              [dance, house, pop]
# 4      2020      2020-08-13           45                      [dancehall]
# ...     ...             ...          ...                              ...
# 4724   2015      2015-09-25           63                     [show-tunes]
# 4725   2013      2013-05-27           32                     [show-tunes]
# 4726   2005      2005-02-26           17                          [tango]
# 4727   2002      2002-08-13           29                     [show-tunes]
# 4728   2006      2006-09-11           72  [singer-songwriter, songwriter]
#
# [4729 rows x 40 columns]

# %%
final_df_pandas.drop('2_artists', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_artists': 'artists'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  1_explicit  \
# 0          The New Abnormal                ['The Strokes']       False
# 1                     Bloom            ['Lights & Motion']       False
# 2               Pink Season                   ['Pink Guy']        True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']       False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']        True
#
#   2_explicit  1_danceability 2_danceability  1_energy 2_energy  ...  \
# 0      False          0.4280          0.426     0.617    0.617  ...
# 1      False          0.0789         0.0789     0.160     0.16  ...
# 2       True          0.8700           0.87     0.597    0.597  ...
# 3      False          0.6970          0.697     0.683    0.683  ...
# 4       True          0.6710          0.671     0.646    0.646  ...
#
#    2_time_signature                                       1_artist_ids  \
# 0               4.0                         ['0epOFNiUfyON9EYx7Tpr6V']
# 1               4.0                         ['3ff1CmU6qfTqRAmdrq8EEG']
# 2               4.0                         ['3yJnBqAoRUNeDabdYoiYWD']
# 3               4.0                         ['1zNqDE7qDGCsyzJwohVaoX']
# 4               4.0  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...
#
#                1_album_id 1_track_number  1_disc_number 1_duration_ms  1_year  \
# 0  2xkZV2Hl1Omi8rk2D7t5lN              9              1        351787    2020
# 1  4N11Xw4rtuswjOeZjqKgay              4              1        176373    2018
# 2  3l5PdpQHvUOXlq1w9PftPu             11              1        117361    2017
# 3  7lPoGKpCGgdKFAxpudhAH5             10              1        186987    2018
# 4  218CJKDCszsQQj7Amk7vIu             12              1        217541    2020
#
#   1_release_date  2_popularity        2_track_genre
# 0     2020-04-10            67   [alt-rock, garage]
# 1     2018-02-02            49            [ambient]
# 2     2017-01-04            39             [comedy]
# 3     2018-04-27            82  [dance, house, pop]
# 4     2020-08-13            45          [dancehall]
#
# [5 rows x 39 columns]

# %%
(str(final_df_pandas['1_explicit']) == final_df_pandas['2_explicit']).all()
# Out:
# False

# %%
# convert 2_explicit type from string to boolean
final_df_pandas['2_explicit'] = final_df_pandas['2_explicit'].map({'True': True, 'False': False})

# %%
final_df_pandas[final_df_pandas['1_explicit'] != final_df_pandas['2_explicit']]
# Out:
#                     track_id                       track_name  \
# 621   32OlwWuMpZ6b0aN2RZOeMS   Uptown Funk (feat. Bruno Mars)
# 1759  0q7oMII7kWTj1ZSX6GT6LU                 Crawl Outta Love
# 1984  525GY0mXYnxajolwgS8Eaz                   Cooler Than Me
# 2000  19m23w2ANVhtB7rApM6pbN                        Back To U
# 2088  4nRyBgsqXEP2oPfzaMeZr7                             Once
# 2618  4n7jnSxVLd8QioibtTDBDq                        On My Way
# 2652  62nQ8UZVqR2RMvkJHkcO2o                           Jeremy
# 2695  2r9hCNjupNy2C2g3r6SNz6    Strongest (Alan Walker Remix)
# 3344  0Q3SC6kEhxYagDP3bFe5K9  Keep It Mello (feat. Omar LinX)
# 3369  45bE4HXI0AwGZXfZtMp8JR               you broke me first
# 3670  4ig3DcNoj3UfPdhL2Rw9J1                        Turbulent
# 4164  7cdy4PbCdDZZNjyxoZyE0c                         Vacation
# 4626  6mz1fBdKATx6qP4oP1I65G                             Pony
#
#                          album_name  \
# 621                  Uptown Special
# 1759                          Awake
# 1984                 Cooler Than Me
# 2000                      Back To U
# 2088                            Ten
# 2618                      On My Way
# 2652                            Ten
# 2695  Strongest (Alan Walker Remix)
# 3344                        Joytime
# 3369             you broke me first
# 3670                         FANDOM
# 4164                       Vacation
# 4626   R&B: From Doo-Wop To Hip-Hop
#
#                                               artists  1_explicit  2_explicit  \
# 621                     ['Mark Ronson', 'Bruno Mars']       False        True
# 1759                     ['ILLENIUM', 'Annika Wells']       False        True
# 1984                                   ['Lucky Luke']       False        True
# 2000                     ['SLANDER', 'William Black']       False        True
# 2088                                    ['Pearl Jam']       False        True
# 2618  ['Alan Walker', 'Sabrina Carpenter', 'Farruko']       False        True
# 2652                                    ['Pearl Jam']       False        True
# 2695                  ['Ina Wroldsen', 'Alan Walker']       False        True
# 3344                      ['Omar LinX', 'Marshmello']       False        True
# 3369                                   ['Tate McRae']       False        True
# 3670                                   ['Waterparks']       False        True
# 4164                                  ['Dirty Heads']       False        True
# 4626                                     ['Ginuwine']       False        True
#
#       1_danceability 2_danceability  1_energy 2_energy  ...  2_time_signature  \
# 621            0.856          0.856     0.609    0.609  ...               4.0
# 1759           0.376          0.377     0.723    0.723  ...               4.0
# 1984           0.889          0.889     0.716    0.716  ...               4.0
# 2000           0.586          0.586     0.499    0.499  ...               4.0
# 2088           0.413          0.413     0.885    0.885  ...               4.0
# 2618           0.509          0.509     0.689    0.689  ...               4.0
# 2652           0.285          0.285     0.846    0.846  ...               4.0
# 2695           0.722          0.722     0.787    0.787  ...               4.0
# 3344           0.686          0.686     0.888    0.888  ...               4.0
# 3369           0.642          0.667     0.374    0.373  ...               4.0
# 3670           0.532          0.532     0.841    0.841  ...               4.0
# 4164           0.739          0.736     0.754    0.751  ...               4.0
# 4626           0.749          0.749     0.605    0.605  ...               4.0
#
#                                            1_artist_ids  \
# 621   ['3hv9jJF3adDNsBSIQDqcjp', '0du5cEVh5yTK9QJze8...
# 1759  ['45eNHdiiabvmbp4erw26rg', '0kErUwb6xgWfkdn0Ry...
# 1984                         ['5ee4yhrWOxaxvL77BoVpVR']
# 2000  ['20DZAfCuP1TKZl5KcY7z3Q', '7d5SfGXKpgS3JK8BFI...
# 2088                         ['1w5Kfo2jwwIPruYS2UWh56']
# 2618  ['7vk5e3vY1uw9plTHJAMwjN', '74KM79TiuVKeVCqs8Q...
# 2652                         ['1w5Kfo2jwwIPruYS2UWh56']
# 2695  ['7hssUdpvtY5oiARaUDgFZ3', '7vk5e3vY1uw9plTHJA...
# 3344  ['6fSNDuge2fLINdnCCbpZx6', '64KEffDW9EtZ1y2vBY...
# 3369                         ['45dkTj5sMRSjrmBSBeiHym']
# 3670                         ['3QaxveoTiMetZCMp1sftiu']
# 4164                         ['6GkJh85o22LfD2vgL9DP6f']
# 4626                         ['7r8RF1tN2A4CiGEplkp1oP']
#
#                   1_album_id 1_track_number  1_disc_number 1_duration_ms  \
# 621   3vLaOYCNCzngDf8QdBg2V1              4              1        269667
# 1759  5rvIgXvAPGWspXY4rDLkeU              2              1        242012
# 1984  5BmY6ZPLmhyIm9bRdN4mWP              1              1        179760
# 2000  0hKOffv9vWtya3CkEXrVhO              1              1        214400
# 2088  5B4PYA7wNN4WdEXdIJu58a              1              1        231368
# 2618  1bcvtuHyO79DNAOOhHEkEm              1              1        193798
# 2652  5B4PYA7wNN4WdEXdIJu58a              6              1        318227
# 2695  3d1YhgZvB8NLZLakA5l4rk              1              1        210286
# 3344  6opKASPALOkPwCfHvqIS9H             10              1        243380
# 3369  1RWiRfdNZKDe8VXzzf2VEc              1              1        169266
# 3670  6W5NAcsq5dV2vMcxPFWXTb              8              1        162577
# 4164  7xR5BJoQg0x0bHac8GMipk              1              1        209142
# 4626  4he7R24eqd1EbF9kegiAK8             18              2        251733
#
#       1_year 1_release_date  2_popularity          2_track_genre
# 621     2015     2015-01-12            83                [dance]
# 1759    2017     2017-09-21            59         [dub, dubstep]
# 1984    2019     2019-05-17            71  [electro, electronic]
# 2000    2020     2020-04-24            57         [dub, dubstep]
# 2088    1991     1991-08-27            58               [grunge]
# 2618    2019     2019-03-21            74       [electro, house]
# 2652    1991     1991-08-27            71               [grunge]
# 2695    2017     2017-12-01            66                [house]
# 3344    2016     2016-01-08            60    [progressive-house]
# 3369    2020     2020-04-17            84                  [pop]
# 3670    2019     2019-10-11            66      [punk-rock, punk]
# 4164    2017     2017-06-30            66               [reggae]
# 4626    1999     1999-10-08            73                 [soul]
#
# [13 rows x 39 columns]

# %%
final_df_pandas.drop('1_explicit', axis=1, inplace=True)
final_df_pandas.rename(columns={'2_explicit': 'explicit'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    1_danceability 2_danceability  1_energy 2_energy  1_key  ...  \
# 0          0.4280          0.426     0.617    0.617      1  ...
# 1          0.0789         0.0789     0.160     0.16      7  ...
# 2          0.8700           0.87     0.597    0.597      7  ...
# 3          0.6970          0.697     0.683    0.683      1  ...
# 4          0.6710          0.671     0.646    0.646      7  ...
#
#   2_time_signature                                       1_artist_ids  \
# 0              4.0                         ['0epOFNiUfyON9EYx7Tpr6V']
# 1              4.0                         ['3ff1CmU6qfTqRAmdrq8EEG']
# 2              4.0                         ['3yJnBqAoRUNeDabdYoiYWD']
# 3              4.0                         ['1zNqDE7qDGCsyzJwohVaoX']
# 4              4.0  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...
#
#                1_album_id  1_track_number 1_disc_number  1_duration_ms 1_year  \
# 0  2xkZV2Hl1Omi8rk2D7t5lN               9             1         351787   2020
# 1  4N11Xw4rtuswjOeZjqKgay               4             1         176373   2018
# 2  3l5PdpQHvUOXlq1w9PftPu              11             1         117361   2017
# 3  7lPoGKpCGgdKFAxpudhAH5              10             1         186987   2018
# 4  218CJKDCszsQQj7Amk7vIu              12             1         217541   2020
#
#    1_release_date 2_popularity        2_track_genre
# 0      2020-04-10           67   [alt-rock, garage]
# 1      2018-02-02           49            [ambient]
# 2      2017-01-04           39             [comedy]
# 3      2018-04-27           82  [dance, house, pop]
# 4      2020-08-13           45          [dancehall]
#
# [5 rows x 38 columns]

# %%
(final_df_pandas['1_danceability'] == final_df_pandas['2_danceability']).all()
# Out:
# False

# %%
final_df_pandas[final_df_pandas['1_danceability'] != final_df_pandas['2_danceability']]
# Out:
#                     track_id                              track_name  \
# 0     1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1     2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2     2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3     2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4     2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
# ...                      ...                                     ...
# 4724  6oF8ueLn5hIl4PRp17sxW6                    That Would Be Enough
# 4725  2qf1Cbi3mIFzVnKERuNwx5                          In This Corner
# 4726  4NUomtCzWb8WNW1DOjCa8A                                El Flete
# 4727  2gVNHsFCboH2rih4HZvRmQ                            It Takes Two
# 4728  3SktMqZmo3M9zbB7oKMIF7                                 Gravity
#
#                                           album_name  \
# 0                                   The New Abnormal
# 1                                              Bloom
# 2                                        Pink Season
# 3                           Speak Your Mind (Deluxe)
# 4                                      Twice As Tall
# ...                                              ...
# 4724     Hamilton (Original Broadway Cast Recording)
# 4725  Kinky Boots (Original Broadway Cast Recording)
# 4726                                    De Pura Cepa
# 4727    Hairspray (Original Broadway Cast Recording)
# 4728                                       Continuum
#
#                                                 artists  explicit  \
# 0                                       ['The Strokes']     False
# 1                                   ['Lights & Motion']     False
# 2                                          ['Pink Guy']      True
# 3                                        ['Anne-Marie']     False
# 4                         ['Burna Boy', 'Chris Martin']      True
# ...                                                 ...       ...
# 4724             ['Phillipa Soo', 'Lin-Manuel Miranda']     False
# 4725  ['Billy Porter', 'Tory Ross', 'Daniel Stewart ...     False
# 4726            ["Juan D'Arienzo y su Orquesta Típica"]     False
# 4727  ['Matthew Morrison', 'Marissa Jaret Winokur', ...     False
# 4728                                     ['John Mayer']     False
#
#       1_danceability 2_danceability  1_energy 2_energy  1_key  ...  \
# 0             0.4280          0.426     0.617    0.617      1  ...
# 1             0.0789         0.0789     0.160     0.16      7  ...
# 2             0.8700           0.87     0.597    0.597      7  ...
# 3             0.6970          0.697     0.683    0.683      1  ...
# 4             0.6710          0.671     0.646    0.646      7  ...
# ...              ...            ...       ...      ...    ...  ...
# 4724          0.4990          0.499     0.200      0.2      2  ...
# 4725          0.6890          0.689     0.726    0.726      5  ...
# 4726          0.8480          0.848     0.381    0.381      9  ...
# 4727          0.3140          0.314     0.553    0.553      9  ...
# 4728          0.7640          0.753     0.326    0.326      7  ...
#
#      2_time_signature                                       1_artist_ids  \
# 0                 4.0                         ['0epOFNiUfyON9EYx7Tpr6V']
# 1                 4.0                         ['3ff1CmU6qfTqRAmdrq8EEG']
# 2                 4.0                         ['3yJnBqAoRUNeDabdYoiYWD']
# 3                 4.0                         ['1zNqDE7qDGCsyzJwohVaoX']
# 4                 4.0  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...
# ...               ...                                                ...
# 4724              4.0  ['2OEGI2wrCVmvavKEOMlccy', '4aXXDj9aZnlshx7mzj...
# 4725              4.0  ['3sjUEh7eXUEL5oZLAEZXD4', '5zwDN0Orwiu22wYaxl...
# 4726              4.0                         ['3EZYBGl6qytwvUPRBVQgOP']
# 4727              3.0  ['3Fx1vJHj530oWC2AxnZq5z', '4zdCODAJOsWFl6I9H7...
# 4728              3.0                         ['0hEurMDQu99nJRq8pTxO14']
#
#                   1_album_id  1_track_number 1_disc_number  1_duration_ms  \
# 0     2xkZV2Hl1Omi8rk2D7t5lN               9             1         351787
# 1     4N11Xw4rtuswjOeZjqKgay               4             1         176373
# 2     3l5PdpQHvUOXlq1w9PftPu              11             1         117361
# 3     7lPoGKpCGgdKFAxpudhAH5              10             1         186987
# 4     218CJKDCszsQQj7Amk7vIu              12             1         217541
# ...                      ...             ...           ...            ...
# 4724  1kCHru7uhxBUdzkm4gzRQc              17             1         178446
# 4725  0VfNZpKsykX5WPuyEdBilR              11             1         296800
# 4726  02OrTuXLp4AT6uGFiEVYeB               9             1         173640
# 4727  3XPjEfpawBvohxBMDXwXXW               6             1         186027
# 4728  1Xsprdt1q9rOzTic7b9zYM               4             1         245827
#
#      1_year  1_release_date 2_popularity                    2_track_genre
# 0      2020      2020-04-10           67               [alt-rock, garage]
# 1      2018      2018-02-02           49                        [ambient]
# 2      2017      2017-01-04           39                         [comedy]
# 3      2018      2018-04-27           82              [dance, house, pop]
# 4      2020      2020-08-13           45                      [dancehall]
# ...     ...             ...          ...                              ...
# 4724   2015      2015-09-25           63                     [show-tunes]
# 4725   2013      2013-05-27           32                     [show-tunes]
# 4726   2005      2005-02-26           17                          [tango]
# 4727   2002      2002-08-13           29                     [show-tunes]
# 4728   2006      2006-09-11           72  [singer-songwriter, songwriter]
#
# [4729 rows x 38 columns]

# %%
final_df_pandas.drop('2_danceability', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_danceability': 'danceability'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  1_energy 2_energy  1_key 2_key  ...  2_time_signature  \
# 0        0.4280     0.617    0.617      1     1  ...               4.0
# 1        0.0789     0.160     0.16      7     7  ...               4.0
# 2        0.8700     0.597    0.597      7     7  ...               4.0
# 3        0.6970     0.683    0.683      1     1  ...               4.0
# 4        0.6710     0.646    0.646      7     7  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#   1_track_number  1_disc_number 1_duration_ms  1_year 1_release_date  \
# 0              9              1        351787    2020     2020-04-10
# 1              4              1        176373    2018     2018-02-02
# 2             11              1        117361    2017     2017-01-04
# 3             10              1        186987    2018     2018-04-27
# 4             12              1        217541    2020     2020-08-13
#
#    2_popularity        2_track_genre
# 0            67   [alt-rock, garage]
# 1            49            [ambient]
# 2            39             [comedy]
# 3            82  [dance, house, pop]
# 4            45          [dancehall]
#
# [5 rows x 37 columns]

# %%
final_df_pandas.drop('2_energy', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_energy': 'energy'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  1_key 2_key  1_loudness  ... 2_time_signature  \
# 0        0.4280   0.617      1     1      -5.424  ...              4.0
# 1        0.0789   0.160      7     7     -18.144  ...              4.0
# 2        0.8700   0.597      7     7      -6.320  ...              4.0
# 3        0.6970   0.683      1     1      -2.881  ...              4.0
# 4        0.6710   0.646      7     7      -7.513  ...              4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number 1_disc_number  1_duration_ms 1_year  1_release_date  \
# 0               9             1         351787   2020      2020-04-10
# 1               4             1         176373   2018      2018-02-02
# 2              11             1         117361   2017      2017-01-04
# 3              10             1         186987   2018      2018-04-27
# 4              12             1         217541   2020      2020-08-13
#
#    2_popularity        2_track_genre
# 0            67   [alt-rock, garage]
# 1            49            [ambient]
# 2            39             [comedy]
# 3            82  [dance, house, pop]
# 4            45          [dancehall]
#
# [5 rows x 36 columns]

# %%
final_df_pandas.drop('2_key', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_key': 'key'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  1_loudness 2_loudness  ...  2_time_signature  \
# 0        0.4280   0.617    1      -5.424     -5.423  ...               4.0
# 1        0.0789   0.160    7     -18.144    -18.144  ...               4.0
# 2        0.8700   0.597    7      -6.320      -6.32  ...               4.0
# 3        0.6970   0.683    1      -2.881     -2.881  ...               4.0
# 4        0.6710   0.646    7      -7.513     -7.513  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#   1_track_number  1_disc_number 1_duration_ms  1_year  1_release_date  \
# 0              9              1        351787    2020      2020-04-10
# 1              4              1        176373    2018      2018-02-02
# 2             11              1        117361    2017      2017-01-04
# 3             10              1        186987    2018      2018-04-27
# 4             12              1        217541    2020      2020-08-13
#
#    2_popularity        2_track_genre
# 0            67   [alt-rock, garage]
# 1            49            [ambient]
# 2            39             [comedy]
# 3            82  [dance, house, pop]
# 4            45          [dancehall]
#
# [5 rows x 35 columns]

# %%
final_df_pandas.drop('2_loudness', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_loudness': 'loudness'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  1_mode  ... 2_time_signature  \
# 0        0.4280   0.617    1    -5.424       0  ...              4.0
# 1        0.0789   0.160    7   -18.144       1  ...              4.0
# 2        0.8700   0.597    7    -6.320       1  ...              4.0
# 3        0.6970   0.683    1    -2.881       0  ...              4.0
# 4        0.6710   0.646    7    -7.513       0  ...              4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number 1_disc_number  1_duration_ms  1_year  1_release_date  \
# 0               9             1         351787    2020      2020-04-10
# 1               4             1         176373    2018      2018-02-02
# 2              11             1         117361    2017      2017-01-04
# 3              10             1         186987    2018      2018-04-27
# 4              12             1         217541    2020      2020-08-13
#
#   2_popularity        2_track_genre
# 0           67   [alt-rock, garage]
# 1           49            [ambient]
# 2           39             [comedy]
# 3           82  [dance, house, pop]
# 4           45          [dancehall]
#
# [5 rows x 34 columns]

# %%
final_df_pandas.drop('2_mode', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_mode': 'mode'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  2_time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...               4.0
# 1        0.0789   0.160    7   -18.144     1  ...               4.0
# 2        0.8700   0.597    7    -6.320     1  ...               4.0
# 3        0.6970   0.683    1    -2.881     0  ...               4.0
# 4        0.6710   0.646    7    -7.513     0  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#   1_track_number  1_disc_number  1_duration_ms  1_year 1_release_date  \
# 0              9              1         351787    2020     2020-04-10
# 1              4              1         176373    2018     2018-02-02
# 2             11              1         117361    2017     2017-01-04
# 3             10              1         186987    2018     2018-04-27
# 4             12              1         217541    2020     2020-08-13
#
#    2_popularity        2_track_genre
# 0            67   [alt-rock, garage]
# 1            49            [ambient]
# 2            39             [comedy]
# 3            82  [dance, house, pop]
# 4            45          [dancehall]
#
# [5 rows x 33 columns]

# %%
final_df_pandas.drop('2_speechiness', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_speechiness': 'speechiness'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  2_time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...               4.0
# 1        0.0789   0.160    7   -18.144     1  ...               4.0
# 2        0.8700   0.597    7    -6.320     1  ...               4.0
# 3        0.6970   0.683    1    -2.881     0  ...               4.0
# 4        0.6710   0.646    7    -7.513     0  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number  1_disc_number  1_duration_ms 1_year  1_release_date  \
# 0               9              1         351787   2020      2020-04-10
# 1               4              1         176373   2018      2018-02-02
# 2              11              1         117361   2017      2017-01-04
# 3              10              1         186987   2018      2018-04-27
# 4              12              1         217541   2020      2020-08-13
#
#   2_popularity        2_track_genre
# 0           67   [alt-rock, garage]
# 1           49            [ambient]
# 2           39             [comedy]
# 3           82  [dance, house, pop]
# 4           45          [dancehall]
#
# [5 rows x 32 columns]

# %%
final_df_pandas.drop('2_acousticness', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_acousticness': 'acousticness'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  2_time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...               4.0
# 1        0.0789   0.160    7   -18.144     1  ...               4.0
# 2        0.8700   0.597    7    -6.320     1  ...               4.0
# 3        0.6970   0.683    1    -2.881     0  ...               4.0
# 4        0.6710   0.646    7    -7.513     0  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number  1_disc_number 1_duration_ms  1_year 1_release_date  \
# 0               9              1        351787    2020     2020-04-10
# 1               4              1        176373    2018     2018-02-02
# 2              11              1        117361    2017     2017-01-04
# 3              10              1        186987    2018     2018-04-27
# 4              12              1        217541    2020     2020-08-13
#
#    2_popularity        2_track_genre
# 0            67   [alt-rock, garage]
# 1            49            [ambient]
# 2            39             [comedy]
# 3            82  [dance, house, pop]
# 4            45          [dancehall]
#
# [5 rows x 31 columns]

# %%
(final_df_pandas['1_instrumentalness'] == final_df_pandas['2_instrumentalness']).all()
# Out:
# False

# %%
final_df_pandas[final_df_pandas['1_instrumentalness'] != final_df_pandas['2_instrumentalness']][['1_instrumentalness', '2_instrumentalness']]
# Out:
#       1_instrumentalness  2_instrumentalness
# 0               0.179000            0.181000
# 1               0.786000            0.786000
# 29              0.000047            0.000051
# 83              0.000887            0.000887
# 89              0.010800            0.010500
# ...                  ...                 ...
# 4710            0.010900            0.011800
# 4719            0.016800            0.015400
# 4720            0.822000            0.822000
# 4721            0.612000            0.614000
# 4728            0.001300            0.001310
#
# [611 rows x 2 columns]

# %%
final_df_pandas.drop('1_instrumentalness', axis=1, inplace=True)
final_df_pandas.rename(columns={'2_instrumentalness': 'instrumentalness'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  2_time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...               4.0
# 1        0.0789   0.160    7   -18.144     1  ...               4.0
# 2        0.8700   0.597    7    -6.320     1  ...               4.0
# 3        0.6970   0.683    1    -2.881     0  ...               4.0
# 4        0.6710   0.646    7    -7.513     0  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number 1_disc_number  1_duration_ms 1_year  1_release_date  \
# 0               9             1         351787   2020      2020-04-10
# 1               4             1         176373   2018      2018-02-02
# 2              11             1         117361   2017      2017-01-04
# 3              10             1         186987   2018      2018-04-27
# 4              12             1         217541   2020      2020-08-13
#
#    2_popularity        2_track_genre
# 0            67   [alt-rock, garage]
# 1            49            [ambient]
# 2            39             [comedy]
# 3            82  [dance, house, pop]
# 4            45          [dancehall]
#
# [5 rows x 30 columns]

# %%
final_df_pandas.drop('2_liveness', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_liveness': 'liveness'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  2_time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...               4.0
# 1        0.0789   0.160    7   -18.144     1  ...               4.0
# 2        0.8700   0.597    7    -6.320     1  ...               4.0
# 3        0.6970   0.683    1    -2.881     0  ...               4.0
# 4        0.6710   0.646    7    -7.513     0  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number  1_disc_number 1_duration_ms  1_year  1_release_date  \
# 0               9              1        351787    2020      2020-04-10
# 1               4              1        176373    2018      2018-02-02
# 2              11              1        117361    2017      2017-01-04
# 3              10              1        186987    2018      2018-04-27
# 4              12              1        217541    2020      2020-08-13
#
#    2_popularity        2_track_genre
# 0            67   [alt-rock, garage]
# 1            49            [ambient]
# 2            39             [comedy]
# 3            82  [dance, house, pop]
# 4            45          [dancehall]
#
# [5 rows x 29 columns]

# %%
final_df_pandas.drop('2_valence', axis=1, inplace=True)
final_df_pandas.rename(columns={'1_valence': 'valence'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  2_time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...               4.0
# 1        0.0789   0.160    7   -18.144     1  ...               4.0
# 2        0.8700   0.597    7    -6.320     1  ...               4.0
# 3        0.6970   0.683    1    -2.881     0  ...               4.0
# 4        0.6710   0.646    7    -7.513     0  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number  1_disc_number  1_duration_ms  1_year  1_release_date  \
# 0               9              1         351787    2020      2020-04-10
# 1               4              1         176373    2018      2018-02-02
# 2              11              1         117361    2017      2017-01-04
# 3              10              1         186987    2018      2018-04-27
# 4              12              1         217541    2020      2020-08-13
#
#    2_popularity        2_track_genre
# 0            67   [alt-rock, garage]
# 1            49            [ambient]
# 2            39             [comedy]
# 3            82  [dance, house, pop]
# 4            45          [dancehall]
#
# [5 rows x 28 columns]

# %%
final_df_pandas.drop('1_tempo', axis=1, inplace=True)
final_df_pandas.rename(columns={'2_tempo': 'tempo'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  2_time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...               4.0
# 1        0.0789   0.160    7   -18.144     1  ...               4.0
# 2        0.8700   0.597    7    -6.320     1  ...               4.0
# 3        0.6970   0.683    1    -2.881     0  ...               4.0
# 4        0.6710   0.646    7    -7.513     0  ...               4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number  1_disc_number  1_duration_ms  1_year  1_release_date  \
# 0               9              1         351787    2020      2020-04-10
# 1               4              1         176373    2018      2018-02-02
# 2              11              1         117361    2017      2017-01-04
# 3              10              1         186987    2018      2018-04-27
# 4              12              1         217541    2020      2020-08-13
#
#   2_popularity        2_track_genre
# 0           67   [alt-rock, garage]
# 1           49            [ambient]
# 2           39             [comedy]
# 3           82  [dance, house, pop]
# 4           45          [dancehall]
#
# [5 rows x 27 columns]

# %%
final_df_pandas.drop('1_time_signature', axis=1, inplace=True)
final_df_pandas.rename(columns={'2_time_signature': 'time_signature'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...             4.0
# 1        0.0789   0.160    7   -18.144     1  ...             4.0
# 2        0.8700   0.597    7    -6.320     1  ...             4.0
# 3        0.6970   0.683    1    -2.881     0  ...             4.0
# 4        0.6710   0.646    7    -7.513     0  ...             4.0
#
#                                         1_artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number  1_disc_number  1_duration_ms  1_year 1_release_date  \
# 0               9              1         351787    2020     2020-04-10
# 1               4              1         176373    2018     2018-02-02
# 2              11              1         117361    2017     2017-01-04
# 3              10              1         186987    2018     2018-04-27
# 4              12              1         217541    2020     2020-08-13
#
#   2_popularity        2_track_genre
# 0           67   [alt-rock, garage]
# 1           49            [ambient]
# 2           39             [comedy]
# 3           82  [dance, house, pop]
# 4           45          [dancehall]
#
# [5 rows x 26 columns]

# %%
final_df_pandas.rename(columns={'1_artist_ids': 'artist_ids'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...             4.0
# 1        0.0789   0.160    7   -18.144     1  ...             4.0
# 2        0.8700   0.597    7    -6.320     1  ...             4.0
# 3        0.6970   0.683    1    -2.881     0  ...             4.0
# 4        0.6710   0.646    7    -7.513     0  ...             4.0
#
#                                           artist_ids              1_album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    1_track_number  1_disc_number  1_duration_ms  1_year 1_release_date  \
# 0               9              1         351787    2020     2020-04-10
# 1               4              1         176373    2018     2018-02-02
# 2              11              1         117361    2017     2017-01-04
# 3              10              1         186987    2018     2018-04-27
# 4              12              1         217541    2020     2020-08-13
#
#   2_popularity        2_track_genre
# 0           67   [alt-rock, garage]
# 1           49            [ambient]
# 2           39             [comedy]
# 3           82  [dance, house, pop]
# 4           45          [dancehall]
#
# [5 rows x 26 columns]

# %%
final_df_pandas.rename(columns={'1_album_id': 'album_id'}, inplace=True)
final_df_pandas.head()

# %%
final_df_pandas.rename(columns={'1_track_number': 'track_number'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...             4.0
# 1        0.0789   0.160    7   -18.144     1  ...             4.0
# 2        0.8700   0.597    7    -6.320     1  ...             4.0
# 3        0.6970   0.683    1    -2.881     0  ...             4.0
# 4        0.6710   0.646    7    -7.513     0  ...             4.0
#
#                                           artist_ids                album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    track_number  1_disc_number  1_duration_ms  1_year 1_release_date  \
# 0             9              1         351787    2020     2020-04-10
# 1             4              1         176373    2018     2018-02-02
# 2            11              1         117361    2017     2017-01-04
# 3            10              1         186987    2018     2018-04-27
# 4            12              1         217541    2020     2020-08-13
#
#   2_popularity        2_track_genre
# 0           67   [alt-rock, garage]
# 1           49            [ambient]
# 2           39             [comedy]
# 3           82  [dance, house, pop]
# 4           45          [dancehall]
#
# [5 rows x 26 columns]

# %%
final_df_pandas.rename(columns={'1_disc_number': 'disc_number'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...             4.0
# 1        0.0789   0.160    7   -18.144     1  ...             4.0
# 2        0.8700   0.597    7    -6.320     1  ...             4.0
# 3        0.6970   0.683    1    -2.881     0  ...             4.0
# 4        0.6710   0.646    7    -7.513     0  ...             4.0
#
#                                           artist_ids                album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    track_number  disc_number  1_duration_ms  1_year 1_release_date  \
# 0             9            1         351787    2020     2020-04-10
# 1             4            1         176373    2018     2018-02-02
# 2            11            1         117361    2017     2017-01-04
# 3            10            1         186987    2018     2018-04-27
# 4            12            1         217541    2020     2020-08-13
#
#   2_popularity        2_track_genre
# 0           67   [alt-rock, garage]
# 1           49            [ambient]
# 2           39             [comedy]
# 3           82  [dance, house, pop]
# 4           45          [dancehall]
#
# [5 rows x 26 columns]

# %%
final_df_pandas.rename(columns={'1_duration_ms': 'duration_ms'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...             4.0
# 1        0.0789   0.160    7   -18.144     1  ...             4.0
# 2        0.8700   0.597    7    -6.320     1  ...             4.0
# 3        0.6970   0.683    1    -2.881     0  ...             4.0
# 4        0.6710   0.646    7    -7.513     0  ...             4.0
#
#                                           artist_ids                album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    track_number  disc_number  duration_ms  1_year 1_release_date 2_popularity  \
# 0             9            1       351787    2020     2020-04-10           67
# 1             4            1       176373    2018     2018-02-02           49
# 2            11            1       117361    2017     2017-01-04           39
# 3            10            1       186987    2018     2018-04-27           82
# 4            12            1       217541    2020     2020-08-13           45
#
#          2_track_genre
# 0   [alt-rock, garage]
# 1            [ambient]
# 2             [comedy]
# 3  [dance, house, pop]
# 4          [dancehall]
#
# [5 rows x 26 columns]

# %%
final_df_pandas.rename(columns={'1_year': 'year'}, inplace=True)
final_df_pandas.head()

# %%
final_df_pandas.rename(columns={'1_release_date': 'release_date'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...             4.0
# 1        0.0789   0.160    7   -18.144     1  ...             4.0
# 2        0.8700   0.597    7    -6.320     1  ...             4.0
# 3        0.6970   0.683    1    -2.881     0  ...             4.0
# 4        0.6710   0.646    7    -7.513     0  ...             4.0
#
#                                           artist_ids                album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    track_number  disc_number  duration_ms  year release_date 2_popularity  \
# 0             9            1       351787  2020   2020-04-10           67
# 1             4            1       176373  2018   2018-02-02           49
# 2            11            1       117361  2017   2017-01-04           39
# 3            10            1       186987  2018   2018-04-27           82
# 4            12            1       217541  2020   2020-08-13           45
#
#          2_track_genre
# 0   [alt-rock, garage]
# 1            [ambient]
# 2             [comedy]
# 3  [dance, house, pop]
# 4          [dancehall]
#
# [5 rows x 26 columns]

# %%
final_df_pandas.rename(columns={'2_popularity': 'popularity'}, inplace=True)
final_df_pandas['popularity'] = final_df_pandas['popularity'].astype(int)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...             4.0
# 1        0.0789   0.160    7   -18.144     1  ...             4.0
# 2        0.8700   0.597    7    -6.320     1  ...             4.0
# 3        0.6970   0.683    1    -2.881     0  ...             4.0
# 4        0.6710   0.646    7    -7.513     0  ...             4.0
#
#                                           artist_ids                album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    track_number  disc_number  duration_ms  year release_date popularity  \
# 0             9            1       351787  2020   2020-04-10         67
# 1             4            1       176373  2018   2018-02-02         49
# 2            11            1       117361  2017   2017-01-04         39
# 3            10            1       186987  2018   2018-04-27         82
# 4            12            1       217541  2020   2020-08-13         45
#
#          2_track_genre
# 0   [alt-rock, garage]
# 1            [ambient]
# 2             [comedy]
# 3  [dance, house, pop]
# 4          [dancehall]
#
# [5 rows x 26 columns]

# %%
final_df_pandas.rename(columns={'2_track_genre': 'track_genre'}, inplace=True)
final_df_pandas.head()
# Out:
#                  track_id                              track_name  \
# 0  1BLOVHYYlH4JUHQGcpt75R                         Ode To The Mets
# 1  2No1A7ZuMaBGxz45jmA9Gw                                Glaciers
# 2  2v738AcSrqklWKhBpV5alf                              Uber Pussy
# 3  2BgEsaKNfHUdlh97KmvFyo                                    2002
# 4  2cerDm5EbuTNJ68EIMtrF2  Monsters You Made (feat. Chris Martin)
#
#                  album_name                        artists  explicit  \
# 0          The New Abnormal                ['The Strokes']     False
# 1                     Bloom            ['Lights & Motion']     False
# 2               Pink Season                   ['Pink Guy']      True
# 3  Speak Your Mind (Deluxe)                 ['Anne-Marie']     False
# 4             Twice As Tall  ['Burna Boy', 'Chris Martin']      True
#
#    danceability  energy  key  loudness  mode  ...  time_signature  \
# 0        0.4280   0.617    1    -5.424     0  ...             4.0
# 1        0.0789   0.160    7   -18.144     1  ...             4.0
# 2        0.8700   0.597    7    -6.320     1  ...             4.0
# 3        0.6970   0.683    1    -2.881     0  ...             4.0
# 4        0.6710   0.646    7    -7.513     0  ...             4.0
#
#                                           artist_ids                album_id  \
# 0                         ['0epOFNiUfyON9EYx7Tpr6V']  2xkZV2Hl1Omi8rk2D7t5lN
# 1                         ['3ff1CmU6qfTqRAmdrq8EEG']  4N11Xw4rtuswjOeZjqKgay
# 2                         ['3yJnBqAoRUNeDabdYoiYWD']  3l5PdpQHvUOXlq1w9PftPu
# 3                         ['1zNqDE7qDGCsyzJwohVaoX']  7lPoGKpCGgdKFAxpudhAH5
# 4  ['3wcj11K77LjEY1PkEazffa', '0LQoZQIV0mIs0y0XQb...  218CJKDCszsQQj7Amk7vIu
#
#    track_number  disc_number  duration_ms  year release_date popularity  \
# 0             9            1       351787  2020   2020-04-10         67
# 1             4            1       176373  2018   2018-02-02         49
# 2            11            1       117361  2017   2017-01-04         39
# 3            10            1       186987  2018   2018-04-27         82
# 4            12            1       217541  2020   2020-08-13         45
#
#            track_genre
# 0   [alt-rock, garage]
# 1            [ambient]
# 2             [comedy]
# 3  [dance, house, pop]
# 4          [dancehall]
#
# [5 rows x 26 columns]

# %%
final_df_pandas.dtypes
# Out:
# track_id             object
# track_name           object
# album_name           object
# artists              object
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature      float64
# artist_ids           object
# album_id             object
# track_number          int64
# disc_number           int64
# duration_ms           int64
# year                  int64
# release_date         object
# popularity            int64
# track_genre          object
# dtype: object

# %%
# save final_df_pandas to csv file
OUTPUT_CSV_PATH = 'Dataset/spotify_merged.csv'
final_df_pandas.to_csv(OUTPUT_CSV_PATH, index=False)
